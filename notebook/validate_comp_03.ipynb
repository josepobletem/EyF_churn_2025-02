# %%
import pandas as pd

# %%
data_02 = pd.read_csv(r'/home/josep/gcp_run/EyF_churn_2025-02/data/raw/competencia_03_crudo.csv')
data_02.shape
# Out:
# (165093, 154)

# %%
data_03 = pd.read_parquet(r'/home/josep/gcp_run/EyF_churn_2025-02/data/raw/competencia_03_crudo_append.parquet')
data_03.shape
# Out:
# (4883051, 154)
