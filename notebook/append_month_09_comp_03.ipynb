# %%
import pandas as pd

# %%
data_02 = pd.read_csv(r'C:\dev\EyF_churn_2025-02\data\raw\competencia_02_crudo.csv')
data_sept = pd.read_csv(r'C:\dev\EyF_churn_2025-02\data\raw\competencia_03_crudo.csv')

# %%
data_sept = pd.read_csv(r'C:\dev\EyF_churn_2025-02\data\raw\competencia_03_crudo.csv')

# %%
data_sept.shape
# Out:
# (165093, 154)

# %%
df3 = pd.concat([data_02, data_sept], ignore_index=True)

# %%
assert len(df3) == len(data_02) + len(data_sept), "La cantidad de filas no coincide con la suma de df1 y df2"

# %%
assert set(df3.columns) == set(data_02.columns) == set(data_sept.columns), "Las columnas no coinciden entre los dataframes"

# %%
df3.to_parquet(
    "C:\dev\EyF_churn_2025-02\data\processed\competencia_03_crudo_append.parquet",
    index=False,
    engine="pyarrow"   # o "fastparquet" si usas ese
)

# %%
! pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ------- -------------------------------- 5.0/28.1 MB 27.4 MB/s eta 0:00:01
#    -------------- ------------------------- 10.0/28.1 MB 24.8 MB/s eta 0:00:01
#    --------------------- ------------------ 14.9/28.1 MB 24.1 MB/s eta 0:00:01
#    -------------------------- ------------- 18.9/28.1 MB 23.4 MB/s eta 0:00:01
#    --------------------------------- ------ 23.6/28.1 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 22.3 MB/s  0:00:01
# ...

# %%
df_loaded = pd.read_parquet("C:\dev\EyF_churn_2025-02\data\processed\competencia_03_crudo_append.parquet")

# %%
df_loaded.shape
# Out:
# (4883051, 154)

# %%
data_02.shape
# Out:
# (4717958, 154)

# %%
df_loaded.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221323    201901               1            0         1
# 1          249227600    201901               1            0         1
# 2          249227813    201901               1            0         0
# 3          249231391    201901               1            0         1
# 4          249244739    201901               1            0         1
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            44                  69          86.33              14610.01
# 1            40                 254        2096.06              15905.41
# 2            77                 156        1071.07              10295.09
# 3            55                 252         979.98               7670.48
# 4            64                 296        2724.67              36225.32
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# ...

# %%
df3.to_csv(
    "C:\dev\EyF_churn_2025-02\data\processed\competencia_03_crudo_append.csv",
    index=False,
)
